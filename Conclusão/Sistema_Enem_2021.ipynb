# %% [markdown]
# <a href="https://colab.research.google.com/github/Gus-1003/ENEM_2021-Data_analysis/blob/main/Conclus%C3%A3o/Sistema_Enem_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas

# %%
# Biblioteca Pandas: usada para manipulação de dados em formato tabular, facilitando a análise e processamento desses dados;
import pandas as pd

# NumPy oferece operações matemáticas poderosas para arrays e matrizes;
import numpy as np

# A biblioteca Matplotlib é uma das mais usadas para visualização de dados, oferecendo diversas ferramentas e opções de plotagem;
import matplotlib.pyplot as plt

# A biblioteca Seaborn é construída em cima do Matplotlib, adicionando ainda mais recursos para criar gráficos mais sofisticados e visualmente atraentes.
import seaborn as sns

# %%
# importe da biblioteca drive do Google Colab, que é usada para fazer a conexão com o Google Drive.
from google.colab import drive

# o método mount() para montar o Google Drive na sessão atual do Colab. Isso significa que a sessão do Colab agora terá acesso aos arquivos armazenados no Google Drive.
drive.mount('/content/drive/')

''' comando %cd é usado para mudar o diretório atual para a pasta MyDrive dentro do Google Drive, para que os arquivos dentro dessa
pasta possam ser facilmente acessados pelo código em Python que será executado na sessão do Colab.'''

# %cd /content/drive/MyDrive/
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive

# %% [markdown]
# # Leitura dataset:

# %%
microdados = '/content/drive/MyDrive/Pesquisa_Enem/Base de Dados/MICRODADOS_ENEM_2021.csv'

# %%
# Divide o caminho do arquivo e obtém o nome do frame
nome_completo = microdados.split('/')
nome = nome_completo[6].split('_')
amostra = nome[2]
print(microdados)
# Out:
# /content/drive/MyDrive/Pesquisa_Enem/Base de Dados/MICRODADOS_ENEM_2021.csv

# %%
"""Para carregar os dados em Python, você pode usar a função read_csv() do pandas para carregar dados de um arquivo CSV,
ou outras funções semelhantes para carregar dados de outros tipos de arquivos:"""

dados = pd.read_csv(microdados, encoding='latin-1', delimiter=";", quotechar='"', usecols=['TP_PRESENCA_CN', 'CO_PROVA_CN','NU_NOTA_CN','TX_RESPOSTAS_CN'])
dados
# Out:
#          TP_PRESENCA_CN  CO_PROVA_CN  NU_NOTA_CN  \
# 0                     0          NaN         NaN
# 1                     1        912.0       505.9
# 2                     0          NaN         NaN
# 3                     1        911.0       580.7
# 4                     1        912.0       497.7
# ...                 ...          ...         ...
# 3389827               0          NaN         NaN
# 3389828               0          NaN         NaN
# 3389829               0          NaN         NaN
# 3389830               1       1048.0       563.7
# 3389831               0          NaN         NaN
#
#                                        TX_RESPOSTAS_CN
# 0                                                  NaN
# 1        DCBCCBDBCCCCCCDDCDCCCACCABCCECCCCAADCCCBBCADE
# 2                                                  NaN
# 3        CCABBDAEDBEBEDDCAAABBDAADBDCACACEDAABCEABAEBC
# 4        BABCDCCBEBCD.DEDCABCBDEDAABEDADBDBCDECCAEDBCB
# ...                                                ...
# 3389827                                            NaN
# 3389828                                            NaN
# 3389829                                            NaN
# 3389830  BDDCACBDEEACEBCDADBDABECCBABEAEBDCDCDBBCDBAAD
# 3389831                                            NaN
#
# [3389832 rows x 4 columns]

# %% [markdown]
# # Pré-processamento:

# %% [markdown]
# ## Garantia da Presença:

# %%
'''O argumento index do método drop() é utilizado para remover as linhas que foram selecionadas, utilizando o atributo index do DataFrame resultante
da seleção: dados[dados.TP_PRESENCA_CN == 0].index.'''

# Apagando o registro dos alunos ausentes:
dados = dados.drop(index=dados[dados.TP_PRESENCA_CN == 0].index)

# Apagando o registro dos alunos eliminados:
dados = dados.drop(index=dados[dados.TP_PRESENCA_CN == 2].index)

dados.shape
# Out:
# (2245844, 4)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2245844 entries, 1 to 3389830
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   TP_PRESENCA_CN   int64
#  1   CO_PROVA_CN      float64
#  2   NU_NOTA_CN       float64
#  3   TX_RESPOSTAS_CN  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 85.7+ MB

# %% [markdown]
# ## Remoção dos outros tipos de Prova:

# %%
dados['CO_PROVA_CN'].value_counts()
# Out:
# 910.0     540520
# 911.0     534778
# 912.0     534535
# 909.0     533925
# 1046.0     16489
# 1047.0     16228
# 1048.0     16174
# 1045.0     16083
# 1014.0      8623
# 1011.0      8585
# 1012.0      8514
# 1013.0      8474
# 917.0        874
# 990.0        449
# 992.0        431
# 989.0        430
# 991.0        421
# 916.0        311
# Name: CO_PROVA_CN, dtype: int64

# %%
dados.drop(dados[dados['CO_PROVA_CN'] > 912].index, inplace = True)
dados['CO_PROVA_CN'].value_counts()
# Out:
# 910.0    540520
# 911.0    534778
# 912.0    534535
# 909.0    533925
# Name: CO_PROVA_CN, dtype: int64

# %%
dados
# Out:
#          TP_PRESENCA_CN  CO_PROVA_CN  NU_NOTA_CN  \
# 1                     1        912.0       505.9
# 3                     1        911.0       580.7
# 4                     1        912.0       497.7
# 8                     1        910.0       487.4
# 9                     1        909.0       507.6
# ...                 ...          ...         ...
# 3109728               1        911.0       387.9
# 3109730               1        910.0       452.4
# 3109733               1        912.0       407.2
# 3109734               1        911.0       540.8
# 3109735               1        910.0       614.2
#
#                                        TX_RESPOSTAS_CN
# 1        DCBCCBDBCCCCCCDDCDCCCACCABCCECCCCAADCCCBBCADE
# 3        CCABBDAEDBEBEDDCAAABBDAADBDCACACEDAABCEABAEBC
# 4        BABCDCCBEBCD.DEDCABCBDEDAABEDADBDBCDECCAEDBCB
# 8        BBBDCCBDCCEDBBBCACEBCDADEEADCDEBEDDEBBEBEEECB
# 9        BAEDEBDECCEAEDDCBDEDAEECEEEDBDECBDCECBCCDABED
# ...                                                ...
# 3109728  DEBDACEBAEADCBAAEDAEDADCDBEBCDBCCBABCDDACEEDB
# 3109730  BACECDAEBACDDAABADCCCADAEDEBEEBDCACEBADCEBDEA
# 3109733  CADDDDDEEECBDCBAAADCBCEDCBACADCAEEEEDDADBEDCD
# 3109734  CCCCABADEDAABBAEBCBDDECCBBCABBDCEDDACEADAECBB
# 3109735  ACCDCC.DDEDACBACDCCACBDEBDECCAABEECABCABDDEDE
#
# [2143758 rows x 4 columns]

# %% [markdown]
# ## Reset index:

# %%
'''o método reset_index() do objeto DataFrame do pandas para redefinir o índice das linhas do DataFrame dados.'''

dados.reset_index(drop=True, inplace=True)

# %%
dados.drop('TP_PRESENCA_CN', axis=1, inplace=True)
dados.head()
# Out:
#    CO_PROVA_CN  NU_NOTA_CN                                TX_RESPOSTAS_CN
# 0        912.0       505.9  DCBCCBDBCCCCCCDDCDCCCACCABCCECCCCAADCCCBBCADE
# 1        911.0       580.7  CCABBDAEDBEBEDDCAAABBDAADBDCACACEDAABCEABAEBC
# 2        912.0       497.7  BABCDCCBEBCD.DEDCABCBDEDAABEDADBDBCDECCAEDBCB
# 3        910.0       487.4  BBBDCCBDCCEDBBBCACEBCDADEEADCDEBEDDEBBEBEEECB
# 4        909.0       507.6  BAEDEBDECCEAEDDCBDEDAEECEEEDBDECBDCECBCCDABED

# %% [markdown]
# # Processamento:

# %% [markdown]
# ## Separando as questões:

# %%
# Identificando a quantidade de quetões - Esse código é um exemplo de como criar uma lista com os valores de uma coluna específica de um DataFrame do pandas.
questoes = []

for i, gabarito in enumerate(list(dados['TX_RESPOSTAS_CN'].loc[0:])):
  questoes.append(gabarito)

# %% [markdown]
# ## Listando as respostas:

# %%
# Construindo as listas de repostas
respostas = []

for i in range(45):
  respostas.append([aluno[i] for aluno in questoes])

# %% [markdown]
# ## Renomeando as questões:

# %%
# Renomeando e preenchendo as Colunas do dicionario
for i in range(45):
  dados.loc[:, 'q' + str(i + 1)] = respostas[i]

# %% [markdown]
# # Pré-processamento 2:

# %%
dados
# Out:
#          CO_PROVA_CN  NU_NOTA_CN  \
# 0              912.0       505.9
# 1              911.0       580.7
# 2              912.0       497.7
# 3              910.0       487.4
# 4              909.0       507.6
# ...              ...         ...
# 2143753        911.0       387.9
# 2143754        910.0       452.4
# 2143755        912.0       407.2
# 2143756        911.0       540.8
# 2143757        910.0       614.2
#
#                                        TX_RESPOSTAS_CN q1 q2 q3 q4 q5 q6 q7  \
# 0        DCBCCBDBCCCCCCDDCDCCCACCABCCECCCCAADCCCBBCADE  D  C  B  C  C  B  D
# 1        CCABBDAEDBEBEDDCAAABBDAADBDCACACEDAABCEABAEBC  C  C  A  B  B  D  A
# 2        BABCDCCBEBCD.DEDCABCBDEDAABEDADBDBCDECCAEDBCB  B  A  B  C  D  C  C
# 3        BBBDCCBDCCEDBBBCACEBCDADEEADCDEBEDDEBBEBEEECB  B  B  B  D  C  C  B
# 4        BAEDEBDECCEAEDDCBDEDAEECEEEDBDECBDCECBCCDABED  B  A  E  D  E  B  D
# ...                                                ... .. .. .. .. .. .. ..
# 2143753  DEBDACEBAEADCBAAEDAEDADCDBEBCDBCCBABCDDACEEDB  D  E  B  D  A  C  E
# 2143754  BACECDAEBACDDAABADCCCADAEDEBEEBDCACEBADCEBDEA  B  A  C  E  C  D  A
# 2143755  CADDDDDEEECBDCBAAADCBCEDCBACADCAEEEEDDADBEDCD  C  A  D  D  D  D  D
# 2143756  CCCCABADEDAABBAEBCBDDECCBBCABBDCEDDACEADAECBB  C  C  C  C  A  B  A
# 2143757  ACCDCC.DDEDACBACDCCACBDEBDECCAABEECABCABDDEDE  A  C  C  D  C  C  .
#
#          ... q36 q37 q38 q39 q40 q41 q42 q43 q44 q45
# 0        ...   D   C   C   C   B   B   C   A   D   E
# 1        ...   A   B   C   E   A   B   A   E   B   C
# 2        ...   D   E   C   C   A   E   D   B   C   B
# 3        ...   E   B   B   E   B   E   E   E   C   B
# 4        ...   E   C   B   C   C   D   A   B   E   D
# ...      ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 2143753  ...   B   C   D   D   A   C   E   E   D   B
# 2143754  ...   E   B   A   D   C   E   B   D   E   A
# 2143755  ...   E   D   D   A   D   B   E   D   C   D
# 2143756  ...   A   C   E   A   D   A   E   C   B   B
# 2143757  ...   A   B   C   A   B   D   D   E   D   E
#
# [2143758 rows x 48 columns]

# %% [markdown]
# ## Removendo coluna gabarito:

# %%
dados.drop('TX_RESPOSTAS_CN', axis=1, inplace=True)
dados
# Out:
#          CO_PROVA_CN  NU_NOTA_CN q1 q2 q3 q4 q5 q6 q7 q8  ... q36 q37 q38 q39  \
# 0              912.0       505.9  D  C  B  C  C  B  D  B  ...   D   C   C   C
# 1              911.0       580.7  C  C  A  B  B  D  A  E  ...   A   B   C   E
# 2              912.0       497.7  B  A  B  C  D  C  C  B  ...   D   E   C   C
# 3              910.0       487.4  B  B  B  D  C  C  B  D  ...   E   B   B   E
# 4              909.0       507.6  B  A  E  D  E  B  D  E  ...   E   C   B   C
# ...              ...         ... .. .. .. .. .. .. .. ..  ...  ..  ..  ..  ..
# 2143753        911.0       387.9  D  E  B  D  A  C  E  B  ...   B   C   D   D
# 2143754        910.0       452.4  B  A  C  E  C  D  A  E  ...   E   B   A   D
# 2143755        912.0       407.2  C  A  D  D  D  D  D  E  ...   E   D   D   A
# 2143756        911.0       540.8  C  C  C  C  A  B  A  D  ...   A   C   E   A
# 2143757        910.0       614.2  A  C  C  D  C  C  .  D  ...   A   B   C   A
#
#         q40 q41 q42 q43 q44 q45
# 0         B   B   C   A   D   E
# 1         A   B   A   E   B   C
# 2         A   E   D   B   C   B
# 3         B   E   E   E   C   B
# 4         C   D   A   B   E   D
# ...      ..  ..  ..  ..  ..  ..
# 2143753   A   C   E   E   D   B
# 2143754   C   E   B   D   E   A
# 2143755   D   B   E   D   C   D
# 2143756   D   A   E   C   B   B
# 2143757   B   D   D   E   D   E
#
# [2143758 rows x 47 columns]

# %% [markdown]
# ## Separando os tipos de prova:

# %%
# Separação das provas por cor
enemAzul = dados[dados['CO_PROVA_CN'] == 909].reset_index(drop=True)
enemAmarela = dados[dados['CO_PROVA_CN'] == 910].reset_index(drop=True)
enemCinza = dados[dados['CO_PROVA_CN'] == 911].reset_index(drop=True)
enemRosa = dados[dados['CO_PROVA_CN'] == 912].reset_index(drop=True)

# %% [markdown]
# ## Removendo o codigo da prova:

# %%
enemAmarela = enemAmarela.drop('CO_PROVA_CN', axis=1)
enemAmarela
# Out:
#         NU_NOTA_CN q1 q2 q3 q4 q5 q6 q7 q8 q9  ... q36 q37 q38 q39 q40 q41  \
# 0            487.4  B  B  B  D  C  C  B  D  C  ...   E   B   B   E   B   E
# 1            378.5  A  C  E  E  D  B  C  C  B  ...   A   E   A   C   B   D
# 2            516.3  A  A  E  C  C  D  A  B  C  ...   E   C   C   D   B   B
# 3            595.2  A  D  D  C  C  A  C  A  C  ...   A   E   C   B   C   E
# 4            386.9  B  B  E  C  E  C  D  A  D  ...   B   D   C   E   D   D
# ...            ... .. .. .. .. .. .. .. .. ..  ...  ..  ..  ..  ..  ..  ..
# 540515       399.6  C  A  C  C  E  E  B  D  E  ...   C   E   C   A   C   B
# 540516       389.3  C  C  E  D  E  C  B  A  B  ...   E   C   D   B   E   B
# 540517       563.2  A  B  E  D  C  C  E  B  D  ...   A   B   B   A   E   B
# 540518       452.4  B  A  C  E  C  D  A  E  B  ...   E   B   A   D   C   E
# 540519       614.2  A  C  C  D  C  C  .  D  D  ...   A   B   C   A   B   D
#
#        q42 q43 q44 q45
# 0        E   E   C   B
# 1        C   E   B   D
# 2        E   E   D   E
# 3        D   A   C   E
# 4        A   D   E   D
# ...     ..  ..  ..  ..
# 540515   C   A   A   C
# 540516   B   D   A   C
# 540517   C   D   A   E
# 540518   B   D   E   A
# 540519   D   E   D   E
#
# [540520 rows x 46 columns]

# %% [markdown]
# ## Renomeando a coluna "Nota":

# %%
enemAmarela = enemAmarela.rename(columns={'NU_NOTA_CN': 'nota'})

# %% [markdown]
# # Ordenando as questões:

# %% [markdown]
# ## Azul:

# %% [markdown]
# ### Organizando:

# %%
enemAzul = enemAzul.loc[:, ['NU_NOTA_CN', 'q42', 'q43', 'q44', 'q45', 'q37', 'q38', 'q39', 'q40', 'q41', 'q31',
                            'q32', 'q33', 'q16', 'q17', 'q36', 'q34', 'q35', 'q26', 'q27', 'q28',
                            'q9', 'q10', 'q11', 'q29', 'q30', 'q18', 'q19', 'q20', 'q13', 'q14',
                            'q15', 'q21', 'q22', 'q23', 'q24', 'q25', 'q12', 'q4', 'q5', 'q6',
                            'q7', 'q8', 'q1', 'q2', 'q3']]

enemAzul.head() # Ordem corrigida
# Out:
#    NU_NOTA_CN q42 q43 q44 q45 q37 q38 q39 q40 q41  ... q25 q12 q4 q5 q6 q7 q8  \
# 0       507.6   A   B   E   D   C   B   C   C   D  ...   E   A  D  E  B  D  E
# 1       650.9   A   C   A   D   C   D   B   C   D  ...   C   D  C  A  B  E  C
# 2       388.1   C   B   C   E   A   C   C   D   C  ...   D   E  C  D  D  A  C
# 3       521.0   A   B   C   D   C   C   B   B   D  ...   C   D  B  D  C  D  C
# 4       531.9   D   D   D   B   E   C   D   C   C  ...   A   D  D  A  E  E  A
#
#   q1 q2 q3
# 0  B  A  E
# 1  E  C  E
# 2  D  C  A
# 3  B  A  C
# 4  E  B  E
#
# [5 rows x 46 columns]

# %% [markdown]
# ### Renomeando:

# %%
enemAzul = enemAzul.rename(columns={'q42': 'q1', 'q43': 'q2', 'q44': 'q3', 'q45': 'q4', 'q37': 'q5',
                                    'q38': 'q6', 'q39': 'q7', 'q40': 'q8', 'q41': 'q9', 'q31': 'q10',
                                    'q32': 'q11', 'q33': 'q12', 'q16': 'q13', 'q17': 'q14', 'q36': 'q15',
                                    'q34': 'q16', 'q35': 'q17', 'q26': 'q18', 'q27': 'q19', 'q28': 'q20',
                                    'q9': 'q21', 'q10': 'q22', 'q11': 'q23', 'q29': 'q24', 'q30': 'q25',
                                    'q18': 'q26', 'q19': 'q27', 'q20': 'q28', 'q13': 'q29', 'q14': 'q30',
                                    'q15': 'q31', 'q21': 'q32', 'q22': 'q33', 'q23': 'q34', 'q24': 'q35',
                                    'q25': 'q36', 'q12': 'q37', 'q4': 'q38', 'q5': 'q39', 'q6': 'q40',
                                    'q7': 'q41', 'q8': 'q42', 'q1': 'q43', 'q2': 'q44', 'q3': 'q45', 'NU_NOTA_CN': 'nota'}).reset_index(drop=True)

enemAzul.head() # Colunas Renomeadas
# Out:
#     nota q1 q2 q3 q4 q5 q6 q7 q8 q9  ... q36 q37 q38 q39 q40 q41 q42 q43 q44  \
# 0  507.6  A  B  E  D  C  B  C  C  D  ...   E   A   D   E   B   D   E   B   A
# 1  650.9  A  C  A  D  C  D  B  C  D  ...   C   D   C   A   B   E   C   E   C
# 2  388.1  C  B  C  E  A  C  C  D  C  ...   D   E   C   D   D   A   C   D   C
# 3  521.0  A  B  C  D  C  C  B  B  D  ...   C   D   B   D   C   D   C   B   A
# 4  531.9  D  D  D  B  E  C  D  C  C  ...   A   D   D   A   E   E   A   E   B
#
#   q45
# 0   E
# 1   E
# 2   A
# 3   C
# 4   E
#
# [5 rows x 46 columns]

# %% [markdown]
# ## Cinza:

# %% [markdown]
# ### Organizando:

# %%
#ProvaCinza
enemCinza = enemCinza.loc[:, ['NU_NOTA_CN', 'q36', 'q37', 'q38', 'q39', 'q1', 'q2', 'q3',
                              'q4', 'q5', 'q33', 'q34', 'q35', 'q19', 'q20', 'q32', 'q30',
                              'q31', 'q21', 'q22', 'q23', 'q24', 'q25', 'q26', 'q14', 'q15',
                              'q27', 'q28', 'q29', 'q16', 'q17', 'q18', 'q41', 'q42', 'q43',
                              'q44', 'q45', 'q40', 'q6', 'q7', 'q8','q9', 'q10', 'q11', 'q12', 'q13']]

enemCinza.head()
# Out:
#    NU_NOTA_CN q36 q37 q38 q39 q1 q2 q3 q4 q5  ... q45 q40 q6 q7 q8 q9 q10 q11  \
# 0       580.7   A   B   C   E  C  C  A  B  B  ...   C   A  D  A  E  D   B   E
# 1       462.2   B   B   C   B  C  D  B  A  D  ...   B   D  C  B  A  B   D   B
# 2       487.9   A   D   E   A  C  D  C  D  D  ...   A   A  A  E  B  D   E   B
# 3       447.4   B   C   E   D  E  A  C  D  C  ...   B   B  B  D  C  E   D   A
# 4       548.1   C   D   E   A  C  C  A  E  C  ...   E   D  C  A  D  E   A   A
#
#   q12 q13
# 0   B   E
# 1   B   E
# 2   A   B
# 3   E   E
# 4   D   D
#
# [5 rows x 46 columns]

# %% [markdown]
# ### Renomeando:

# %%
enemCinza = enemCinza.rename(columns={'q36': 'q1', 'q37': 'q2', 'q38': 'q3', 'q39': 'q4', 'q1': 'q5', 'q2': 'q6', 'q3': 'q7',
               'q4': 'q8', 'q5': 'q9', 'q33': 'q10', 'q34': 'q11', 'q35': 'q12', 'q19': 'q13', 'q20': 'q14',
               'q32': 'q15', 'q30': 'q16', 'q31': 'q17', 'q21': 'q18', 'q22': 'q19', 'q23': 'q20', 'q24': 'q21',
               'q25': 'q22', 'q26': 'q23', 'q14': 'q24', 'q15': 'q25', 'q27': 'q26', 'q28': 'q27', 'q29': 'q28',
               'q16': 'q29', 'q17': 'q30', 'q18': 'q31', 'q41': 'q32', 'q42': 'q33', 'q43': 'q34', 'q44': 'q35',
               'q45': 'q36', 'q40': 'q37', 'q6': 'q38', 'q7': 'q39', 'q8': 'q40', 'q9': 'q41', 'q10': 'q42',
               'q11': 'q43', 'q12': 'q44', 'q13': 'q45', 'NU_NOTA_CN': 'nota'}).reset_index(drop=True)

enemCinza.head()
# Out:
#     nota q1 q2 q3 q4 q5 q6 q7 q8 q9  ... q36 q37 q38 q39 q40 q41 q42 q43 q44  \
# 0  580.7  A  B  C  E  C  C  A  B  B  ...   C   A   D   A   E   D   B   E   B
# 1  462.2  B  B  C  B  C  D  B  A  D  ...   B   D   C   B   A   B   D   B   B
# 2  487.9  A  D  E  A  C  D  C  D  D  ...   A   A   A   E   B   D   E   B   A
# 3  447.4  B  C  E  D  E  A  C  D  C  ...   B   B   B   D   C   E   D   A   E
# 4  548.1  C  D  E  A  C  C  A  E  C  ...   E   D   C   A   D   E   A   A   D
#
#   q45
# 0   E
# 1   E
# 2   B
# 3   E
# 4   D
#
# [5 rows x 46 columns]

# %% [markdown]
# ## Rosa:

# %% [markdown]
# ### Organizando:

# %%
enemRosa = enemRosa.loc[:, ['NU_NOTA_CN', 'q26', 'q27', 'q28', 'q29', 'q37', 'q38', 'q39', 'q40', 'q41', 'q23',
                            'q24', 'q25', 'q35', 'q36', 'q1', 'q21', 'q22', 'q32', 'q33', 'q34',
                            'q2', 'q3', 'q4', 'q30', 'q31', 'q18', 'q19', 'q20', 'q42', 'q43',
                            'q44', 'q8', 'q9', 'q10', 'q11', 'q12', 'q45', 'q13', 'q14', 'q15',
                            'q16', 'q17', 'q5', 'q6', 'q7']]

enemRosa.head()
# Out:
#    NU_NOTA_CN q26 q27 q28 q29 q37 q38 q39 q40 q41  ... q12 q45 q13 q14 q15  \
# 0       505.9   B   C   C   E   C   C   C   B   B  ...   C   E   C   C   D
# 1       497.7   A   B   E   D   E   C   C   A   E  ...   D   B   .   D   E
# 2       509.6   A   A   E   A   C   D   C   E   B  ...   E   B   C   D   D
# 3       439.6   D   D   E   B   C   C   A   B   B  ...   E   A   D   C   B
# 4       426.2   A   B   A   C   E   C   D   A   A  ...   C   D   C   A   D
#
#   q16 q17 q5 q6 q7
# 0   D   C  C  B  D
# 1   D   C  D  C  C
# 2   B   C  D  B  D
# 3   D   D  E  A  C
# 4   B   E  E  A  B
#
# [5 rows x 46 columns]

# %% [markdown]
# ### Renomeando:

# %%
enemRosa = enemRosa.rename(columns={'q26': 'q1', 'q27': 'q2', 'q28': 'q3', 'q29': 'q4', 'q37': 'q5',
                                    'q38': 'q6', 'q39': 'q7', 'q40': 'q8', 'q41': 'q9', 'q23': 'q10',
                                    'q24': 'q11', 'q25': 'q12', 'q35': 'q13', 'q36': 'q14', 'q1': 'q15',
                                    'q21': 'q16', 'q22': 'q17', 'q32': 'q18', 'q33': 'q19', 'q34': 'q20',
                                    'q2': 'q21', 'q3': 'q22', 'q4': 'q23', 'q30': 'q24', 'q31': 'q25',
                                    'q18': 'q26', 'q19': 'q27', 'q20': 'q28', 'q42': 'q29', 'q43': 'q30',
                                    'q44': 'q31', 'q8': 'q32', 'q9': 'q33', 'q10': 'q34', 'q11': 'q35',
                                    'q12': 'q36', 'q45': 'q37', 'q13': 'q38', 'q14': 'q39', 'q15': 'q40',
                                    'q16': 'q41', 'q17': 'q42', 'q5': 'q43', 'q6': 'q44', 'q7': 'q45', 'NU_NOTA_CN': 'nota'}).reset_index(drop=True)

enemRosa.head()
# Out:
#     nota q1 q2 q3 q4 q5 q6 q7 q8 q9  ... q36 q37 q38 q39 q40 q41 q42 q43 q44  \
# 0  505.9  B  C  C  E  C  C  C  B  B  ...   C   E   C   C   D   D   C   C   B
# 1  497.7  A  B  E  D  E  C  C  A  E  ...   D   B   .   D   E   D   C   D   C
# 2  509.6  A  A  E  A  C  D  C  E  B  ...   E   B   C   D   D   B   C   D   B
# 3  439.6  D  D  E  B  C  C  A  B  B  ...   E   A   D   C   B   D   D   E   A
# 4  426.2  A  B  A  C  E  C  D  A  A  ...   C   D   C   A   D   B   E   E   A
#
#   q45
# 0   D
# 1   C
# 2   D
# 3   C
# 4   B
#
# [5 rows x 46 columns]

# %% [markdown]
# # Processamento 2:

# %% [markdown]
# ## Concatenando respostas|:

# %%
provaEnem = pd.concat([enemAmarela, enemAzul, enemCinza, enemRosa], ignore_index=True)
display(provaEnem)
# Out:
#           nota q1 q2 q3 q4 q5 q6 q7 q8 q9  ... q36 q37 q38 q39 q40 q41 q42  \
# 0        487.4  B  B  B  D  C  C  B  D  C  ...   E   B   B   E   B   E   E
# 1        378.5  A  C  E  E  D  B  C  C  B  ...   A   E   A   C   B   D   C
# 2        516.3  A  A  E  C  C  D  A  B  C  ...   E   C   C   D   B   B   E
# 3        595.2  A  D  D  C  C  A  C  A  C  ...   A   E   C   B   C   E   D
# 4        386.9  B  B  E  C  E  C  D  A  D  ...   B   D   C   E   D   D   A
# ...        ... .. .. .. .. .. .. .. .. ..  ...  ..  ..  ..  ..  ..  ..  ..
# 2143753  482.0  C  E  C  B  C  B  C  C  B  ...   E   D   D   B   B   D   A
# 2143754  380.9  A  D  D  A  A  D  D  B  E  ...   B   E   D   A   C   C   C
# 2143755  388.8  B  A  C  D  E  C  E  A  B  ...   D   D   C   C   E   D   *
# 2143756  516.3  A  A  C  B  C  C  E  D  B  ...   D   D   C   E   A   E   E
# 2143757  407.2  B  A  C  A  D  D  A  D  B  ...   B   D   D   C   B   A   A
#
#         q43 q44 q45
# 0         E   C   B
# 1         E   B   D
# 2         E   D   E
# 3         A   C   E
# 4         D   E   D
# ...      ..  ..  ..
# 2143753   A   C   B
# 2143754   D   E   A
# 2143755   E   E   D
# 2143756   D   B   D
# 2143757   D   D   D
#
# [2143758 rows x 46 columns]

# %% [markdown]
# ## Dados das respostas:

# %%
# lista com os nomes das colunas que vão ser plotadas
colunas = ['q' + str(i) for i in range(1, 46)]

# criar um DataFrame vazio para armazenar os resultados
resultado = pd.DataFrame()

# loop para iterar sobre as colunas e criar os gráficos
for coluna in colunas:
    # obter os valores de value_counts()
    valores = provaEnem[coluna].value_counts()
    porcentagens = provaEnem[coluna].value_counts(normalize=True)

    # adicionar os valores e porcentagens como colunas no DataFrame resultado
    #resultado[coluna + '_valores'] = valores
    resultado[coluna + '_porcentagens'] = porcentagens

# Ordenar as linhas em ordem alfabética pelas letras que representam as alternativas
resultado = resultado.sort_index()

# exibir o resultado final
resultado
# Out:
#    q1_porcentagens  q2_porcentagens  q3_porcentagens  q4_porcentagens  \
# *         0.000643         0.001018         0.001329         0.001111
# .         0.000944         0.002180         0.001951         0.002052
# A         0.419966         0.239376         0.129798         0.317470
# B         0.229326         0.361371         0.154520         0.158880
# C         0.151723         0.148156         0.249857         0.130529
# D         0.160552         0.170110         0.170522         0.169790
# E         0.036847         0.077789         0.292025         0.220168
#
#    q5_porcentagens  q6_porcentagens  q7_porcentagens  q8_porcentagens  \
# *         0.000801         0.000478         0.000953         0.000935
# .         0.000665         0.003463         0.001302         0.001760
# A         0.050302         0.056202         0.209428         0.177025
# B         0.032968         0.184382         0.245463         0.208454
# C         0.649087         0.410078         0.321460         0.153139
# D         0.088800         0.267491         0.147460         0.304340
# E         0.177376         0.077907         0.073934         0.154348
#
#    q9_porcentagens  q10_porcentagens  ...  q36_porcentagens  q37_porcentagens  \
# *         0.000878          0.000842  ...          0.000827          0.000773
# .         0.001627          0.001113  ...          0.002450          0.001891
# A         0.095646          0.186849  ...          0.254368          0.095238
# B         0.381271          0.156122  ...          0.217085          0.255617
# C         0.206175          0.301873  ...          0.145073          0.158175
# D         0.270614          0.105466  ...          0.215367          0.346232
# E         0.043789          0.247736  ...          0.164831          0.142074
#
#    q38_porcentagens  q39_porcentagens  q40_porcentagens  q41_porcentagens  \
# *          0.000730          0.001210          0.001099          0.000970
# .          0.003485          0.001594          0.002486          0.001035
# A          0.127350          0.307660          0.116643          0.135765
# B          0.224719          0.190811          0.373344          0.171200
# C          0.252225          0.168545          0.173787          0.119361
# D          0.294871          0.191058          0.179723          0.207562
# E          0.096619          0.139122          0.152918          0.364106
#
#    q42_porcentagens  q43_porcentagens  q44_porcentagens  q45_porcentagens
# *          0.000916          0.000911          0.000921          0.001300
# .          0.001358          0.002741          0.001740          0.000842
# A          0.222139          0.219404          0.185449          0.101590
# B          0.154653          0.293934          0.173642          0.189509
# C          0.165599          0.097123          0.276312          0.119201
# D          0.163581          0.140540          0.207858          0.245192
# E          0.291754          0.245345          0.154077          0.342366
#
# [7 rows x 45 columns]

# %%
# Gabarito
gabarito = ['A', 'D', 'C', 'D', 'C', 'D', 'B', 'B', 'B', 'E', 'C', 'D', 'C', 'C', 'D', 'C', 'B', 'C', 'B', 'D', 'A', 'B', 'C', 'A', 'A', 'D', 'C', 'B', 'E', 'B', 'A', 'B', 'E', 'E', 'B', 'B', 'B', 'C', 'A', 'B', 'E', 'D', 'E', 'D', 'E']

# Criando um novo DataFrame com as porcentagens de acerto da questão baseado no gabarito
porcentagens_acerto = pd.DataFrame()

for questao, resposta in enumerate(gabarito, start=1):
    if resposta in resultado.index:
        porcentagens_acerto[f'q{questao}_acerto'] = [resultado.loc[resposta, f'q{questao}_porcentagens']]
    else:
        porcentagens_acerto[f'q{questao}_acerto'] = [0.0]  # Alternativa não encontrada, atribui 0.0

# Exibindo o resultado
porcentagens_acerto
# Out:
#    q1_acerto  q2_acerto  q3_acerto  q4_acerto  q5_acerto  q6_acerto  \
# 0   0.419966    0.17011   0.249857    0.16979   0.649087   0.267491
#
#    q7_acerto  q8_acerto  q9_acerto  q10_acerto  ...  q36_acerto  q37_acerto  \
# 0   0.245463   0.208454   0.381271    0.247736  ...    0.217085    0.255617
#
#    q38_acerto  q39_acerto  q40_acerto  q41_acerto  q42_acerto  q43_acerto  \
# 0    0.252225     0.30766    0.373344    0.364106    0.163581    0.245345
#
#    q44_acerto  q45_acerto
# 0    0.207858    0.342366
#
# [1 rows x 45 columns]

# %% [markdown]
# gabarito = ['A', 'D', 'C', 'D', 'C', 'D', 'B', 'B', 'B', 'E', 'C', 'D', 'C', 'C', 'D', 'C', 'B', 'C', 'B', 'D', 'A', 'B', 'C', 'A', 'A', 'D', 'C', 'B', 'E', 'B', 'A', 'B', 'E', 'E', 'B', 'B', 'B', 'C', 'A', 'B', 'E', 'D', 'E', 'D', 'E']

# %%
# Encontrar a coluna com o maior valor
coluna_maior_valor = porcentagens_acerto.idxmax(axis=1).iloc[0]

# Obter os rótulos das 5 colunas com os maiores valores
maiores_colunas = porcentagens_acerto.iloc[0].nlargest(5).index

# Selecionar as 5 colunas com os maiores valores
dataset_maiores_colunas = porcentagens_acerto[maiores_colunas]

print("Dataset com as 5 colunas que possuem os maiores valores:")
dataset_maiores_colunas
# Out:
# Dataset com as 5 colunas que possuem os maiores valores:
#    q33_acerto  q5_acerto  q21_acerto  q11_acerto  q32_acerto
# 0    0.682434   0.649087    0.531077    0.510166    0.482001

# %%
# Encontrar a coluna com o maior valor
coluna_maior_valor = porcentagens_acerto.idxmax(axis=1).iloc[0]

# Obter os rótulos das 5 colunas com os maiores valores
menores_colunas = porcentagens_acerto.iloc[0].nsmallest(5).index

# Selecionar as 5 colunas com os maiores valores
dataset_menores_colunas = porcentagens_acerto[menores_colunas]

print("Dataset com as 5 colunas que possuem os menores_colunas:")
dataset_menores_colunas
# Out:
# Dataset com as 5 colunas que possuem os menores_colunas:
#    q24_acerto  q42_acerto  q4_acerto  q2_acerto  q30_acerto
# 0    0.110838    0.163581    0.16979    0.17011    0.174228

# %% [markdown]
# # Salvando:

# %%
# salvar o resultado em um arquivo CSV com o nome personalizado

resultado.to_csv("/content/drive/MyDrive/Pesquisa_Enem/Resultados/" + f"resultados_{amostra}")
porcentagens_acerto.to_csv("/content/drive/MyDrive/Pesquisa_Enem/Resultados/" + f"Porcentagem_quests_{amostra}")
dataset_maiores_colunas.to_csv("/content/drive/MyDrive/Pesquisa_Enem/Resultados/" + f"quest_easy_{amostra}")
dataset_menores_colunas.to_csv("/content/drive/MyDrive/Pesquisa_Enem/Resultados/" + f"resquest_hard_{amostra}")

print(f"O dataset foi salvo como resultados.")
# Out:
# O dataset foi salvo como resultados.
